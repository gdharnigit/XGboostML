# %%
import pandas as pd

# %%
df = pd.read_csv('us_stocks.csv')

# %%
df.head(2000)
# Out:
#      ticker        date   open   high    low  close      volume  ex-dividend  \
# 0         A  1999-11-18  45.50  50.00  40.00  44.00  44739900.0          0.0
# 1         A  1999-11-19  42.94  43.00  39.81  40.38  10897100.0          0.0
# 2         A  1999-11-22  41.31  44.00  40.06  44.00   4705200.0          0.0
# 3         A  1999-11-23  42.50  43.63  40.25  40.25   4274400.0          0.0
# 4         A  1999-11-24  40.13  41.94  40.00  41.06   3464400.0          0.0
# ...     ...         ...    ...    ...    ...    ...         ...          ...
# 1995      A  2007-10-26  36.61  37.00  35.44  36.03   1300700.0          0.0
# 1996      A  2007-10-29  36.24  36.49  35.89  36.03   1451600.0          0.0
# 1997      A  2007-10-30  35.88  36.18  35.47  35.86   1199400.0          0.0
# 1998      A  2007-10-31  36.14  36.89  35.84  36.85   1717200.0          0.0
# 1999      A  2007-11-01  36.67  37.06  36.23  36.26   1923100.0          0.0
#
# ...

# %%
df['date'] = pd.to_datetime(df.date)

# %%
df.head(1)
# Out:
#   ticker       date  open  high   low  close      volume
# 0      A 1999-11-18  45.5  50.0  40.0   44.0  44739900.0

# %%
df = df.drop(columns=['ex-dividend','split_ratio','adj_open','adj_high','adj_low','adj_close','adj_volume'])

# %%
df.set_index(['ticker', 'date'])
# Out:
#                     open   high      low  close      volume
# ticker date
# A      1999-11-18  45.50  50.00  40.0000  44.00  44739900.0
#        1999-11-19  42.94  43.00  39.8100  40.38  10897100.0
#        1999-11-22  41.31  44.00  40.0600  44.00   4705200.0
#        1999-11-23  42.50  43.63  40.2500  40.25   4274400.0
#        1999-11-24  40.13  41.94  40.0000  41.06   3464400.0
# ...                  ...    ...      ...    ...         ...
# ZUMZ   2018-03-21  23.80  24.60  23.6058  23.95    354092.0
#        2018-03-22  23.90  24.35  23.3000  23.35    269607.0
#        2018-03-23  23.55  24.20  23.4500  23.55    301584.0
#        2018-03-26  23.75  24.80  23.7000  24.65    375320.0
#        2018-03-27  24.65  24.65  23.3500  23.60    403884.0
#
# [15389314 rows x 5 columns]
